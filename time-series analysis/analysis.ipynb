# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()

# %%
df=pd.read_csv("google trends data.csv",skiprows=1)
df
# Out:
#        الأسبوع.  programming: (في جميع أنحاء العالم)  \
# 0    2020-01-05                                   11
# 1    2020-01-12                                   12
# 2    2020-01-19                                   12
# 3    2020-01-26                                   12
# 4    2020-02-02                                   12
# ..          ...                                  ...
# 257  2024-12-08                                   12
# 258  2024-12-15                                   11
# 259  2024-12-22                                    9
# 260  2024-12-29                                   10
# 261  2025-01-05                                   10
#
#      تحليل بيانات: (في جميع أنحاء العالم)  finance: (في جميع أنحاء العالم)
# 0                                       4                               66
# 1                                       4                               65
# 2                                       4                               65
# ...

# %%
df.columns=["month","programming","data analysis","finance"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month          262 non-null    object
#  1   programming    262 non-null    int64
#  2   data analysis  262 non-null    int64
#  3   finance        262 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 8.3+ KB

# %%
df['month']=pd.to_datetime(df["month"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month          262 non-null    datetime64[ns]
#  1   programming    262 non-null    int64
#  2   data analysis  262 non-null    int64
#  3   finance        262 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 8.3 KB

# %%
df.set_index("month",inplace=True)

# %%
df.head(5)
# Out:
#             programming  data analysis  finance
# month
# 2020-01-05           11              4       66
# 2020-01-12           12              4       65
# 2020-01-19           12              4       65
# 2020-01-26           12              4       66
# 2020-02-02           12              4       71

# %% [markdown]
# exploratory data analysis

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
df["finance"].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# trending data

# %%
df['finance'].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
df["programming"].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
df['programming'].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
df["data analysis"].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
df['data analysis'].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='month'>

# %%
pd.concat([df['programming'].rolling(12).mean(),df['data analysis'].rolling(12).mean()],axis=1)
# Out:
#             programming  data analysis
# month
# 2020-01-05          NaN            NaN
# 2020-01-12          NaN            NaN
# 2020-01-19          NaN            NaN
# 2020-01-26          NaN            NaN
# 2020-02-02          NaN            NaN
# ...                 ...            ...
# 2024-12-08    11.583333       8.916667
# 2024-12-15    11.416667       8.833333
# 2024-12-22    11.166667       8.666667
# 2024-12-29    11.000000       8.500000
# 2025-01-05    10.916667       8.416667
#
# [262 rows x 2 columns]

# %%
pd.concat([df['programming'].rolling(12).mean(),df['data analysis'].rolling(12).mean()],axis=1).plot()
# Out:
# <Axes: xlabel='month'>
